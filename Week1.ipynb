# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreagazy/PCVK-2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
"https://www.newshub.co.nz/home/lifestyle/2019/08/the-top-five-cat-memes-of-all-time-rated/_jcr_content/par/video/image.dynimg.1280.q75.jpg/v1565234972425/KNOWYOURMEME-sad-cat-crying-1120.jpg"
#"https://placekitten.com/800/571"
]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url) #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2)) #convert color to RGB
  cv2_imshow(final_frame) #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=1280x366>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  366  x  640
# <PIL.Image.Image image mode=RGB size=640x366>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y]=[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x366>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range(tinggi):
        image_3[x, int(lebar/2)] = [255, 255, 255] # white color

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x366>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
 # Draw diagonal line from top-left to bottom-right
# diagonal line
  # top-left to bottom-right
for i in range(lebar):
      y = int(i * (tinggi / lebar))
      image_3[y, i] = [255, 255, 255]

  # bottom-left to top-right
for i in range(lebar):
      y = int(tinggi - 1 - (i * (tinggi / lebar)))
      image_3[y, i] = [255, 255, 255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x366>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang = 100
mulai_x = 60
akhir_x = mulai_x + panjang
for x in range(mulai_x, akhir_x):
    image_3[panjang,x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x366>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Daftar area dan warna
area_tertutup = [
    ((100, 100, 200, 200), [255, 255, 255])  # Contoh area dan warna
]

# Mengganti setiap area dengan warna
for (area, warna) in area_tertutup:
    x1, y1, x2, y2 = area
    image_3[y1:y2, x1:x2] = warna

# Menggabungkan gambar asli dan gambar yang telah dimodifikasi
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x366>

# %% [markdown]
# **Pertanyaan**
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ```
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# ```
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# 4. Perhatikan potongan kode progam berikut :
# ```
# for y in range (lebar):
#       image_3[int((tinggi)/2),y]=[255,255,255]
# ```
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# **Jawab**
#
# 1. Karena pada Google Colab sudah memiliki semua library python dan dapat diakses langsung melalui browser tanpa perlu instalasi perangkat lunak tambahan serta terintegrasi dengan Google Drive yang membuat penyimpanan dan pengelolaan file menjadi lebih mudah
# 2. Penjelasan Library Python
#
#   - **`numpy (np)`**:
#    Untuk manipulasi array dan operasi matematika numerik.
#   - **`pandas (pd)`**:
#    Untuk manipulasi dan analisis data tabular menggunakan DataFrame dan Series.
#
#   - **`cv2 (cv)`**:
#    Library OpenCV untuk pemrosesan gambar dan video.
#
#   - **`google.colab.patches (cv2_imshow)`**:
#    Menampilkan gambar dengan OpenCV di Google Colab.
#
#   - **`skimage.io (io)`**:
#    Membaca dan menulis gambar menggunakan `scikit-image`.
#
#   - **`skimage.transform (transform)`**:
#    Melakukan transformasi gambar seperti rotasi dan resize.
#
#   - **`PIL (Image)`**:
#    Untuk membuka, memanipulasi, dan menyimpan gambar.
#
#   - **`matplotlib.pylab (plt)`**:
#    Untuk visualisasi data dan plotting grafik.
#
# 3. Digunakan untuk mengubah ukuran gambar menjadi setengah dari ukuran aslinya. Jika tidak dilakukan, gambar tetap dengan ukuran aslinya, yang mungkin terlalu besar dan bisa mempengaruhi performa aplikasi serta kesulitan dalam visualisasi.
#
# 4. Kode [255,255,255] digunakan untuk sebagai grayscale yang menunjukkan warna putih
#
# 5. Pixel adalah unit terkecil dari gambar digital, dan resolusi gambar menunjukkan jumlah pixel dalam gambar. Resolusi tinggi memiliki banyak pixel, sehingga gambar lebih tajam dan detail. resolusi rendah memiliki sedikit pixel, sehingga gambar kurang tajam dan detail. Semakin banyak pixel, semakin tinggi resolusi dan kualitas gambar.
